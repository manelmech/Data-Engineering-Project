# %%
# %sql
use catalog pricing_analytics;

create schema if not exists bronze; 

create table if not exists daily_pricing(
DATE_OF_PRICING string,
ROW_ID string,
STATE_NAME string,
MARKET_NAME string,
PRODUCTGROUP_NAME string,
PRODUCT_NAME string,
VARIETY string,
ORIGIN string,
ARRIVAL_IN_TONNES string,
MINIMUM_PRICE string,
MAXIMUM_PRICE string, 
MODAL_PRICE string,
source_file_load_date timestamp
) 
using csv
options(
  'delimiter'= ',',
  'header'= 'true')
location 'abfss://bronze@adlsudadalakehousedev.dfs.core.windows.net/daily-pricing/'
