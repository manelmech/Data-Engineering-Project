# %%
import pandas as pds 
 
sourceDataPandasDF = pds.date_range(start="1/1/2023", end= "31/12/2025")
sparkDataSparkDF = spark.createDataFrame(sourceDataPandasDF.to_frame())

# %%
display(sparkDataSparkDF)

# %%
sparkDataSparkDF=sparkDataSparkDF.withColumnRenamed("0","calendar_date")

# %%
display(sparkDataSparkDF)

# %%
sparkDataSparkDF.createOrReplaceTempView('source_date_dim')

# %%
# %sql

truncate table pricing_analytics.gold.reporting_dim_date_gold;
insert into pricing_analytics.gold.reporting_dim_date_gold 
select 
substring(calendar_date,1,10),
date_format(calendar_date,"yyyymmdd" ),
current_timestamp() as lakehouse_inserted_date,
current_timestamp() as lakehouse_inserted_date
from source_date_dim
